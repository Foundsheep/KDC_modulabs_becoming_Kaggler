# %% [markdown]
# #### 파이썬으로 그래프를 그린다는건?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject, points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yuna's Test Result")

# 보여주기
plt.savefig('./barplot.png')  # 그래프를 이미지로 출력
plt.show()                    # 그래프를 화면으로 출력

# %% [markdown]
# ### 9-3. 간단한 그래프 그리기 (1) 막대그래프 그려보기

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# %% [markdown]
# #### 2. 축 그리기

# %%
# 축 그리기
fig = plt.figure() #도화지(그래프) 객체 생성
ax1 = fig.add_subplot(1,1,1) #figure()객체에 add_subplot 메소드를 이용해 축을 그려준다.

# %%
fig = plt.figure()

# %%
fig = plt.figure(figsize=(5,2))
ax1 = fig.add_subplot(1,1,1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,4)

# %% [markdown]
# #### 3. 그래프 그리기

# %%
# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject,points)
# Out:
# <BarContainer object of 5 artists>

# %%
# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject, points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yuna's Test Result")
# Out:
# Text(0.5, 1.0, "Yuna's Test Result")

# %% [markdown]
# ### 9-4. 간단한 그래프 그리기 (2) 선 그래프 그려보기

# %% [markdown]
# #### 1. 데이터 정의

# %%
# DJ's practice

# important_data = [(datetime(2019, 6, 3), "Low Price"),(datetime(2020, 2, 19), "Peak Price")]
# for d, label in important_data:
#     print(d)
#     print(label)
#     print(price.asof(d))
#     print()

# price[datetime(2019,6,3)]
# Out:
# 2019-06-03 00:00:00
# Low Price
# 1692.689941
#
# 2020-02-19 00:00:00
# Peak Price
# 2170.219971
# 1692.689941

# %%
# DJ's practice

# from datetime import datetime
# import pandas as pd
# import os

# fig = plt.figure()
# ax = fig.add_subplot(1,1,1)
# price.plot(ax=ax, style='black')
# plt.ylim((1600,2200))
# plt.xlim(('2019-05-01', '2020-03-01'))

# important_data = [(datetime(2019, 6, 3), "Low Price"),(datetime(2020, 2, 19), "Peak Price")]
# for d, label in important_data:
#     ax.annotate(label, xy=(d, price.asof(d)+10), # 주석을 달 좌표(x,y)
#                 xytext=(d,price.asof(d)+100), # 주석 텍스트가 위차할 좌표(x,y)
#                 arrowprops=dict(facecolor='red')) # 화살표 추가 및 색 설정
# Out:
# (737180.0, 737485.0)

# %%
from datetime import datetime
import pandas as pd
import os

# 그래프 데이터 
csv_path = "AMZN.csv"
data = pd.read_csv(csv_path ,index_col=0, parse_dates=True)
price = data['Close']

# 축 그리기 및 좌표축 설정
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
price.plot(ax=ax, style='black')
plt.ylim([1600,2200])
plt.xlim(['2019-05-01','2020-03-01'])

# 주석달기
important_data = [(datetime(2019, 6, 3), "Low Price"),(datetime(2020, 2, 19), "Peak Price")]
for d, label in important_data:
    ax.annotate(label, xy=(d, price.asof(d)+10), # 주석을 달 좌표(x,y)
                xytext=(d,price.asof(d)+100), # 주석 텍스트가 위차할 좌표(x,y)
                arrowprops=dict(facecolor='red')) # 화살표 추가 및 색 설정

# 그리드, 타이틀 달기
plt.grid()
ax.set_title('StockPrice')

# 보여주기
plt.show()

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-03-25  1757.790039  1782.680054  1747.500000  1774.260010  1774.260010
# 2019-03-26  1793.000000  1805.770020  1773.359985  1783.760010  1783.760010
# 2019-03-27  1784.130005  1787.500000  1745.680054  1765.699951  1765.699951
# 2019-03-28  1770.000000  1777.930054  1753.469971  1773.420044  1773.420044
# 2019-03-29  1786.579956  1792.859985  1776.630005  1780.750000  1780.750000
# ...                 ...          ...          ...          ...          ...
# 2020-03-16  1641.510010  1759.449951  1626.030029  1689.150024  1689.150024
# 2020-03-17  1775.469971  1857.780029  1689.239990  1807.839966  1807.839966
# 2020-03-18  1750.000000  1841.660034  1745.000000  1830.000000  1830.000000
# 2020-03-19  1860.000000  1945.000000  1832.650024  1880.930054  1880.930054
# 2020-03-20  1926.310059  1957.000000  1820.729980  1846.089966  1846.089966
#
#               Volume
# Date
# 2019-03-25   5103800
# 2019-03-26   4865900
# 2019-03-27   4324800
# 2019-03-28   3043000
# 2019-03-29   3320800
# ...              ...
# 2020-03-16   8917300
# 2020-03-17  10917100
# 2020-03-18   9645200
# 2020-03-19  10399900
# 2020-03-20   9807600
#
# [251 rows x 6 columns]

# %% [markdown]
# #### plt.plot()로 그래프 그리기

# %%
import numpy as np
x = np.linspace(0, 10, 100) #0에서 10까지 균등한 간격으로  100개의 숫자를 만들라는 뜻입니다.
plt.plot(x, np.sin(x),'o')
plt.plot(x, np.cos(x),'--', color='black') 
plt.show()

# %%
x = np.linspace(0, 10, 100) 

plt.subplot(2,1,1)
plt.plot(x, np.sin(x),'orange','o')

plt.subplot(2,1,2)
plt.plot(x, np.cos(x), 'orange') 
plt.show()

# %% [markdown]
# #### linestyle, marker옵션

# %%
x = np.linspace(0, 10, 100) 

plt.plot(x, x + 0, linestyle='solid') 
plt.plot(x, x + 1, linestyle='dashed') 
plt.plot(x, x + 2, linestyle='dashdot') 
plt.plot(x, x + 3, linestyle='dotted')
plt.plot(x, x + 0, '-g') # solid green 
plt.plot(x, x + 1, '--c') # dashed cyan 
plt.plot(x, x + 2, '-.k') # dashdot black 
plt.plot(x, x + 3, ':r'); # dotted red
plt.plot(x, x + 4, linestyle='-') # solid 
plt.plot(x, x + 5, linestyle='--') # dashed 
plt.plot(x, x + 6, linestyle='-.') # dashdot 
plt.plot(x, x + 7, linestyle=':'); # dotted

# %% [markdown]
# #### pandas Series or DataFrame의 plot method 사용하기

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(5), index=list('abcde'))
data.plot(kind='bar', ax=axes[0], color='blue', alpha=1)
data.plot(kind='barh', ax=axes[1], color='red', alpha=0.3)

# %%
# # DJ's practice

# f1, f2 = plt.subplots(3,2)

# print(f1)
# print()
# print(f2)
# Out:
# Figure(432x288)
#
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffda779fa50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7ffda77c6150>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffda76fe8d0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7ffda7857110>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffda7889910>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7ffda7a0b150>]]

# %%
# # DJ's practice

# fig, axes = plt.subplots(3,1)
# data = pd.Series(np.random.rand(5), index=list('abcde'))
# data.plot(kind='bar', ax=axes[0], color='blue', alpha=0.2)
# data.plot(kind='barh', ax=axes[1], color='red', alpha=0.3)

# %%
df = pd.DataFrame(np.random.rand(6,4), columns=pd.Index(['A','B','C','D']))
df.plot(kind='line')

# %%
pd.DataFrame(np.random.rand(6,4), columns=['A','B','C','D'])
# Out:
#           A         B         C         D
# 0  0.453312  0.544716  0.575257  0.624117
# 1  0.005660  0.428210  0.753225  0.347250
# 2  0.977912  0.481297  0.880153  0.331061
# 3  0.841212  0.046327  0.313075  0.497873
# 4  0.152108  0.817502  0.228726  0.061064
# 5  0.525145  0.435950  0.570934  0.464476

# %%
# # 정리

# 0. import the library : import matplotlib.pyplot as plt
# 1. figure creation : fig = plt.figure()
# 2. add and ax : ax1 = fig.add_subplot(1,1,1)
# 3. choose the plot type : ax1.bar
# 4. put the data : ax1.bar(x,y)
# 5. put gird or xlabel etc., using methods : plt.grid()
# 6. plt.savefig
